# %% [markdown]
# Data Analytics I:
# https://www.youtube.com/watch?v=QcPycBZomac
# Show linear regression technique for user values.
# Create a Linear Regression Model using Python/R to predict salary of 15
# years of experience using salary_csv file.
# Experience Salary
# 5 20000
# 7 25000
# 9 40000
# 12 60000
# 18 80000
# 20 110000

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import precision_score,r2_score,recall_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=({"Experience":[5,7,9,12,18,20],"Salary":[20000,25000,40000,60000,8000,110000]})

# %%
df=pd.DataFrame(data)
df
# Out:
#    Experience  Salary
# 0           5   20000
# 1           7   25000
# 2           9   40000
# 3          12   60000
# 4          18    8000
# 5          20  110000

# %%
x=df[["Experience"]]
y=df["Salary"]

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict([[15]])
print(y_pred)
# Out:
# [53997.26526892]
# C:\Users\Windows 10\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x,y,color="red")
plt.plot(x,model.predict(x),color="blue")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Salary VS Experience")
plt.show()
